# %% [markdown]
# <a href="https://colab.research.google.com/github/saivinay111234/Time-series-forecasting/blob/main/Time%20Series%20Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import pandas_datareader as web 
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn.metrics import confusion_matrix

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.85)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)

# %%
import plotly.graph_objs as go
import yfinance as yf

# %%
stock=input("enter a stock")
print(stock)
# Out:
# enter a stockGOOGL
# GOOGL

# %%
df = yf.download(tickers=stock,period='1d',interval='1m')
df1=df.head(100)
print(df1)
data=pd.DataFrame(df)
#print the data we have requested
print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                           Open       High        Low      Close  Adj Close  \
# Datetime
# 2022-11-04 09:30:00  85.400002  85.989998  85.400002  85.660004  85.660004
# 2022-11-04 09:31:00  85.660004  85.779999  85.349998  85.377701  85.377701
# 2022-11-04 09:32:00  85.260002  85.260002  85.055000  85.120003  85.120003
# 2022-11-04 09:33:00  85.010002  85.044998  84.904999  85.029999  85.029999
# 2022-11-04 09:34:00  85.089996  85.089996  85.029999  85.050003  85.050003
# ...                        ...        ...        ...        ...        ...
# 2022-11-04 11:05:00  85.330002  85.449997  85.309998  85.320000  85.320000
# 2022-11-04 11:06:00  85.321899  85.339996  85.205002  85.305000  85.305000
# 2022-11-04 11:07:00  85.300003  85.300003  85.099998  85.129997  85.129997
# 2022-11-04 11:08:00  85.110001  85.279999  85.110001  85.169998  85.169998
# 2022-11-04 11:09:00  85.139999  85.139999  85.055000  85.089996  85.089996
#
#                       Volume
# Datetime
# 2022-11-04 09:30:00  2449670
# 2022-11-04 09:31:00   191940
# 2022-11-04 09:32:00   679283
# 2022-11-04 09:33:00   352321
# 2022-11-04 09:34:00   199977
# ...                      ...
# 2022-11-04 11:05:00    99040
# 2022-11-04 11:06:00    79289
# 2022-11-04 11:07:00    88902
# 2022-11-04 11:08:00    60228
# 2022-11-04 11:09:00   122264
#
# [100 rows x 6 columns]
#                           Open       High        Low      Close  Adj Close  \
# Datetime
# 2022-11-04 09:30:00  85.400002  85.989998  85.400002  85.660004  85.660004
# 2022-11-04 09:31:00  85.660004  85.779999  85.349998  85.377701  85.377701
# 2022-11-04 09:32:00  85.260002  85.260002  85.055000  85.120003  85.120003
# 2022-11-04 09:33:00  85.010002  85.044998  84.904999  85.029999  85.029999
# 2022-11-04 09:34:00  85.089996  85.089996  85.029999  85.050003  85.050003
# ...                        ...        ...        ...        ...        ...
# 2022-11-04 15:56:00  86.470001  86.489998  86.410103  86.470001  86.470001
# 2022-11-04 15:57:00  86.470001  86.489998  86.394997  86.434998  86.434998
# 2022-11-04 15:58:00  86.431801  86.529999  86.430000  86.514999  86.514999
# 2022-11-04 15:59:00  86.514999  86.639999  86.510002  86.599998  86.599998
# 2022-11-04 16:00:00  86.580002  86.580002  86.580002  86.580002  86.580002
#
#                       Volume
# Datetime
# 2022-11-04 09:30:00  2449670
# 2022-11-04 09:31:00   191940
# 2022-11-04 09:32:00   679283
# 2022-11-04 09:33:00   352321
# 2022-11-04 09:34:00   199977
# ...                      ...
# 2022-11-04 15:56:00   237407
# 2022-11-04 15:57:00   360047
# 2022-11-04 15:58:00   454192
# 2022-11-04 15:59:00   964084
# 2022-11-04 16:00:00        0
#
# [391 rows x 6 columns]

# %%
df1= yf.download(tickers=stock,period='1d',interval='1m')
print(df1)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                           Open       High        Low      Close  Adj Close  \
# Datetime
# 2022-11-04 09:30:00  85.400002  85.989998  85.400002  85.660004  85.660004
# 2022-11-04 09:31:00  85.660004  85.779999  85.349998  85.377701  85.377701
# 2022-11-04 09:33:00  85.010002  85.044998  84.904999  85.029999  85.029999
# 2022-11-04 09:34:00  85.089996  85.089996  85.029999  85.050003  85.050003
# 2022-11-04 09:35:00  84.949997  84.980003  84.949997  84.971497  84.971497
# ...                        ...        ...        ...        ...        ...
# 2022-11-04 15:56:00  86.470001  86.489998  86.410103  86.470001  86.470001
# 2022-11-04 15:57:00  86.470001  86.489998  86.394997  86.434998  86.434998
# 2022-11-04 15:58:00  86.431801  86.529999  86.430000  86.514999  86.514999
# 2022-11-04 15:59:00  86.514999  86.639999  86.510002  86.599998  86.599998
# 2022-11-04 16:00:00  86.580002  86.580002  86.580002  86.580002  86.580002
#
#                       Volume
# Datetime
# 2022-11-04 09:30:00  2449670
# 2022-11-04 09:31:00   191940
# 2022-11-04 09:33:00  1031604
# 2022-11-04 09:34:00   199977
# 2022-11-04 09:35:00   223880
# ...                      ...
# 2022-11-04 15:56:00   237402
# 2022-11-04 15:57:00   360049
# 2022-11-04 15:58:00   454276
# 2022-11-04 15:59:00   963993
# 2022-11-04 16:00:00        0
#
# [390 rows x 6 columns]

# %% [markdown]
# # **DATA PREPARATION**

# %%
wiki=pd.read_html('https://en.wikipedia.org/wiki/Nasdaq-100#Investing_in_the_NASDAQ-100')
df=pd.DataFrame(wiki[4])
print(df1)
df1=df[df.columns[0:2]]
l1=list(df1['Ticker'])
l2=list(df1['Company'])
print(l2)
len(l1)

# %%
data=pd.DataFrame()
print(data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in l1[0:2]:
  df = yf.download(tickers=i,period='1d',interval='1m')
  print(df)

# %%
k=0
for i in l1[0:2]:
  df = yf.download(tickers=i,period='1d',interval='1m')
  print(df.shape[0])
  df.insert(0,'Stock Symbol',i,True)
  df.insert(1, 'Company',l2[k], True)
  if(k!=len(l2)):
    k=k+1
  else:
    continue
  data=pd.concat([data,df],ignore_index=False)
  print(data)

# %%
k=0
for i in l1:
  df = yf.download(tickers=i,period='1d',interval='1m')
  print(df.shape[0])
  df.insert(0,'Stock Symbol',i,True)
  df.insert(1, 'Company',l2[k], True)
  if(k!=len(l2)):
    k=k+1
  else:
    continue
  data=pd.concat([data,df],ignore_index=False)
  print(data)

# %%
data.to_csv("Top 100 stocks.csv")

# %% [markdown]
# # **Final data code- Method 1**

# %%
wiki=pd.read_html('https://en.wikipedia.org/wiki/Nasdaq-100#Investing_in_the_NASDAQ-100')
df=pd.DataFrame(wiki[4])
# print(df1)
df1=df[df.columns[0:2]]
l1=list(df1['Ticker'])
l2=list(df1['Company'])
# print(l2)
# len(l1)
data=pd.DataFrame()
print(data)
k=0
for i in l1:
  df = yf.download(tickers=i,period='1d',interval='1m')
  print(df.shape[0])
  df.insert(0,'Stock Symbol',i,True)
  df.insert(1, 'Company',l2[k], True)
  if(k!=len(l2)):
    k=k+1
  else:
    continue
  data=pd.concat([data,df],ignore_index=False)
  print(data)

data.to_csv("Top 100 stocks.csv")

# %%
data1=data

# %%
data1.head()
# Out:
#                     Stock Symbol              Company       Open       High  \
# Datetime
# 2022-11-01 09:30:00         ATVI  Activision Blizzard  73.260002  73.699997
# 2022-11-01 09:31:00         ATVI  Activision Blizzard  73.720001  73.790001
# 2022-11-01 09:33:00         ATVI  Activision Blizzard  73.639999  73.650002
# 2022-11-01 09:34:00         ATVI  Activision Blizzard  73.519997  73.580002
# 2022-11-01 09:35:00         ATVI  Activision Blizzard  73.510002  73.680000
#
#                            Low      Close  Adj Close  Volume
# Datetime
# 2022-11-01 09:30:00  73.260002  73.669998  73.669998  257668
# 2022-11-01 09:31:00  73.720001  73.779999  73.779999    3239
# 2022-11-01 09:33:00  73.550003  73.550003  73.550003  179314
# 2022-11-01 09:34:00  73.470001  73.510002  73.510002   10151
# 2022-11-01 09:35:00  73.500000  73.550003  73.550003   27652

# %% [markdown]
# # **Data Preprocessing**

# %%
fin_data=data
fin_data.head(10)
# Out:
#                     Stock Symbol              Company       Open       High  \
# Datetime
# 2022-11-01 09:30:00         ATVI  Activision Blizzard  73.260002  73.699997
# 2022-11-01 09:31:00         ATVI  Activision Blizzard  73.720001  73.790001
# 2022-11-01 09:33:00         ATVI  Activision Blizzard  73.639999  73.650002
# 2022-11-01 09:34:00         ATVI  Activision Blizzard  73.519997  73.580002
# 2022-11-01 09:35:00         ATVI  Activision Blizzard  73.510002  73.680000
# 2022-11-01 09:36:00         ATVI  Activision Blizzard  73.550003  73.599998
# 2022-11-01 09:37:00         ATVI  Activision Blizzard  73.570000  73.620003
# 2022-11-01 09:38:00         ATVI  Activision Blizzard  73.599998  73.599998
# 2022-11-01 09:39:00         ATVI  Activision Blizzard  73.529999  73.559998
# 2022-11-01 09:40:00         ATVI  Activision Blizzard  73.529999  73.550003
#
#                            Low      Close  Adj Close  Volume
# Datetime
# 2022-11-01 09:30:00  73.260002  73.669998  73.669998  257668
# 2022-11-01 09:31:00  73.720001  73.779999  73.779999    3239
# 2022-11-01 09:33:00  73.550003  73.550003  73.550003  179314
# 2022-11-01 09:34:00  73.470001  73.510002  73.510002   10151
# 2022-11-01 09:35:00  73.500000  73.550003  73.550003   27652
# 2022-11-01 09:36:00  73.529999  73.570000  73.570000   42681
# 2022-11-01 09:37:00  73.529999  73.610001  73.610001   16017
# 2022-11-01 09:38:00  73.495003  73.510002  73.510002   33473
# 2022-11-01 09:39:00  73.500000  73.529999  73.529999   15799
# 2022-11-01 09:40:00  73.500000  73.514999  73.514999   14543

# %% [markdown]
# # **Importing the dataset- Method 2**

# %%
df=pd.read_csv("Top 100 stocks.csv")
df.head()
df['Stock Symbol'].unique()
# Out:
# array(['ATVI', 'ADBE', 'ADP', 'ABNB', 'ALGN', 'GOOGL', 'GOOG', 'AMZN',
#        'AMD', 'AEP', 'AMGN', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ASML', 'AZN',
#        'TEAM', 'ADSK', 'BIDU', 'BIIB', 'BKNG', 'AVGO', 'CDNS', 'CHTR',
#        'CTAS', 'CSCO', 'CTSH', 'CMCSA', 'CEG', 'CPRT', 'COST', 'CRWD',
#        'CSX', 'DDOG', 'DXCM', 'DOCU', 'DLTR', 'EBAY', 'EA', 'EXC', 'FAST',
#        'FISV', 'FTNT', 'GILD', 'HON', 'IDXX', 'ILMN', 'INTC', 'INTU',
#        'ISRG', 'JD', 'KDP', 'KLAC', 'KHC', 'LRCX', 'LCID', 'LULU', 'MAR',
#        'MRVL', 'MTCH', 'MELI', 'META', 'MCHP', 'MU', 'MSFT', 'MRNA',
#        'MDLZ', 'MNST', 'NTES', 'NFLX', 'NVDA', 'NXPI', 'ORLY', 'OKTA',
#        'ODFL', 'PCAR', 'PANW', 'PAYX', 'PYPL', 'PEP', 'PDD', 'QCOM',
#        'REGN', 'ROST', 'SGEN', 'SIRI', 'SWKS', 'SPLK', 'SBUX', 'SNPS',
#        'TMUS', 'TSLA', 'TXN', 'VRSN', 'VRSK', 'VRTX', 'WBA', 'WDAY',
#        'XEL', 'ZM', 'ZS'], dtype=object)

# %% [markdown]
# ## **shape of data**

# %%
df.columns
# Out:
# Index(['Datetime', 'Stock Symbol', 'Company', 'Open', 'High', 'Low', 'Close',
#        'Adj Close', 'Volume'],
#       dtype='object')

# %%
df.shape
# Out:
# (38712, 9)

# %% [markdown]
# # **statistics**

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  38712.000000  38712.000000  38712.000000  38712.000000  38712.000000
# mean     178.196415    178.291725    178.095046    178.192862    178.192862
# std      209.541819    209.632191    209.446809    209.540012    209.540012
# min        6.060000      6.060000      6.055000      6.060000      6.060000
# 25%       62.415001     62.439999     62.393750     62.419998     62.419998
# 50%      117.589996    117.629997    117.540001    117.580002    117.580002
# 75%      218.500000    218.552502    218.422497    218.500000    218.500000
# max     1926.989990   1927.000000   1925.750000   1926.744995   1926.744995
#
#              Volume
# count  3.871200e+04
# mean   2.550477e+04
# std    7.522903e+04
# min    0.000000e+00
# 25%    2.037750e+03
# 50%    5.078000e+03
# 75%    1.444100e+04
# max    2.889349e+06

# %% [markdown]
# # **Checking Null values**

# %%
df.isnull().sum()
# Out:
# Datetime        0
# Stock Symbol    0
# Company         0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# dtype: int64

# %% [markdown]
# # **Visualization & Correlation**

# %%
for i in df.columns[3:]:
  print(i)
# Out:
# Open
# High
# Low
# Close
# Adj Close
# Volume

# %%
for i in df.columns[3:]:
  print(i)
  print(df.hist(column=i, bins=50))
# Out:
# Open
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb958d5390>]]
# High
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb957d72d0>]]
# Low
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb9571bf50>]]
# Close
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb95672dd0>]]
# Adj Close
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb95789e10>]]
# Volume
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb955475d0>]]

# %%
df.iloc[:, 3:8].plot(kind='hist',
        alpha=0.7,
        bins=25,
        title='Histogram Of stocks',
        rot=45,
        grid=True,
        figsize=(15,8),
        fontsize=15
        )

# %%
df[df['Stock Symbol']=='TSLA']['Close'].plot(figsize=(16,8))

# %%
df['Close'].plot(figsize=(16,8))

# %%
df_new=df
df_new=df_new.reset_index()

df_new=df_new[['Datetime','Close','Stock Symbol']]
df_new.head()
df_new_pivot=df_new.pivot('Datetime','Stock Symbol', 'Close').reset_index()
df_new_pivot.head()
# Out:
# Stock Symbol         Datetime        AAPL        ABNB        ADBE         ADI  \
# 0             11/1/2022 10:00  152.490005  111.485298  317.899994  144.250000
# 1             11/1/2022 10:01  152.089996  111.139999  318.200012  144.399994
# 2             11/1/2022 10:02  152.210998  111.139999  317.640015  144.460007
# 3             11/1/2022 10:03  152.240005  111.389999  318.299988  144.410004
# 4             11/1/2022 10:04  151.720001  110.654999  317.709992  144.160004
#
# Stock Symbol         ADP        ADSK        AEP        ALGN       AMAT  ...  \
# 0             241.740005  213.630005  88.050003  200.970001  89.910004  ...
# 1             241.404999  213.759995  88.220001  200.710007  90.040001  ...
# 2             241.274994  213.919998  88.169998  201.100006  90.070000  ...
# 3             241.250000  214.509995  88.190002  201.050003  89.970001  ...
# 4             241.154999  213.949997  88.110001  199.880005  89.528297  ...
#
# Stock Symbol        TSLA         TXN        VRSK        VRSN        VRTX  \
# 0             232.261993  161.179993  182.759995  201.279999  312.529999
# 1             232.751907  161.337799  182.869995  201.380005  311.869995
# 2             232.929993  161.500000  183.089996  201.289993  312.536194
# 3             232.850006  161.580002  182.985001  201.470001  312.920013
# 4             232.029999  161.210007  182.764999  200.889999  311.855011
#
# Stock Symbol        WBA        WDAY        XEL         ZM          ZS
# 0             36.509998  155.570007  65.180000  84.662498  154.389999
# 1             36.520000  155.597702  65.285004  84.739998  154.330002
# 2             36.470001  155.399994  65.239998  84.750000  154.360001
# 3             36.439999  155.220001  65.290001  84.589996  154.220001
# 4             36.415001  154.759995  65.269997  84.220001  153.839996
#
# [5 rows x 103 columns]

# %%
corr_df = df_new_pivot.corr(method='pearson')
corr_df.head().reset_index()
corr_df.head(10)
# Out:
# Stock Symbol      AAPL      ABNB      ADBE       ADI       ADP      ADSK  \
# Stock Symbol
# AAPL          1.000000  0.709717  0.854546  0.050750  0.213382  0.831091
# ABNB          0.709717  1.000000  0.495081 -0.009461 -0.238049  0.397944
# ADBE          0.854546  0.495081  1.000000 -0.137552  0.280796  0.838184
# ADI           0.050750 -0.009461 -0.137552  1.000000  0.436310  0.236882
# ADP           0.213382 -0.238049  0.280796  0.436310  1.000000  0.578053
# ADSK          0.831091  0.397944  0.838184  0.236882  0.578053  1.000000
# AEP          -0.553866 -0.481113 -0.628045  0.654876  0.272537 -0.340817
# ALGN          0.660253  0.763236  0.681311 -0.272736 -0.316110  0.386452
# AMAT          0.184410 -0.018558  0.345489 -0.024845  0.198344  0.391651
# AMD           0.695076  0.776760  0.526059  0.296909 -0.173702  0.512536
#
# Stock Symbol       AEP      ALGN      AMAT       AMD  ...      TSLA       TXN  \
# Stock Symbol                                          ...
# AAPL         -0.553866  0.660253  0.184410  0.695076  ...  0.780855  0.064564
# ABNB         -0.481113  0.763236 -0.018558  0.776760  ...  0.831645 -0.314987
# ADBE         -0.628045  0.681311  0.345489  0.526059  ...  0.680160  0.041982
# ADI           0.654876 -0.272736 -0.024845  0.296909  ... -0.134462  0.672130
# ADP           0.272537 -0.316110  0.198344 -0.173702  ... -0.328395  0.871100
# ADSK         -0.340817  0.386452  0.391651  0.512536  ...  0.491144  0.468639
# AEP           1.000000 -0.644508 -0.207171 -0.231296  ... -0.666305  0.462160
# ALGN         -0.644508  1.000000  0.012449  0.722534  ...  0.842350 -0.510407
# AMAT         -0.207171  0.012449  1.000000  0.077806  ...  0.176287  0.266022
# AMD          -0.231296  0.722534  0.077806  1.000000  ...  0.804279 -0.154339
#
# Stock Symbol      VRSK      VRSN      VRTX       WBA      WDAY       XEL  \
# Stock Symbol
# AAPL          0.721111  0.759781 -0.277201  0.863802  0.740346 -0.400409
# ABNB          0.825224  0.855124 -0.361332  0.668459  0.782948 -0.447199
# ADBE          0.602342  0.626471 -0.340468  0.831269  0.699398 -0.474772
# ADI          -0.175758 -0.225273  0.548525  0.009713 -0.224076  0.560865
# ADP          -0.353751 -0.384026  0.609284  0.183188 -0.396880  0.555015
# ADSK          0.390078  0.413670  0.044164  0.713841  0.427550 -0.142204
# AEP          -0.610940 -0.665823  0.634062 -0.485914 -0.689060  0.867590
# ALGN          0.766952  0.870929 -0.533169  0.755806  0.868669 -0.703624
# AMAT          0.169235  0.080930 -0.092888  0.088191  0.166745 -0.015264
# AMD           0.701208  0.786476 -0.242075  0.652850  0.770357 -0.341577
#
# Stock Symbol        ZM        ZS
# Stock Symbol
# AAPL          0.779278  0.953223
# ABNB          0.775356  0.765033
# ADBE          0.766021  0.869164
# ADI          -0.149650 -0.009941
# ADP          -0.277863  0.031980
# ADSK          0.544458  0.736646
# AEP          -0.635819 -0.605219
# ALGN          0.894395  0.795656
# AMAT          0.246182  0.111022
# AMD           0.818992  0.774481
#
# [10 rows x 102 columns]

# %%
plt.figure(figsize=(50, 8))
sns.heatmap(corr_df.head(10), annot=True)
plt.figure()

# %% [markdown]
# line plot of 'CLOSE' for the Apple company.

# %%
df1.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
while(True):
  process=str(input('can we proceed (yes/no) ?'))
  if(process=='yes'):
    print('Choose from list of stocks: ')
    print(df_new['Stock Symbol'].unique())
    stock=(input('Enter the stock symbol: '))
    stock=stock.upper()
    df1= yf.download(tickers=stock,period='1d',interval='1m')
    for i in df1.columns:
      print(df1.plot.line(y=i,use_index=True))
      print("---------- plot for "+ i + " -----------")
  else:
    print("No problem ! ")
    break
# Out:
# can we proceed (yes/no) ?yes
# Choose from list of stocks:
# ['ATVI' 'ADBE' 'ADP' 'ABNB' 'ALGN' 'GOOGL' 'GOOG' 'AMZN' 'AMD' 'AEP'
#  'AMGN' 'ADI' 'ANSS' 'AAPL' 'AMAT' 'ASML' 'AZN' 'TEAM' 'ADSK' 'BIDU'
#  'BIIB' 'BKNG' 'AVGO' 'CDNS' 'CHTR' 'CTAS' 'CSCO' 'CTSH' 'CMCSA' 'CEG'
#  'CPRT' 'COST' 'CRWD' 'CSX' 'DDOG' 'DXCM' 'DOCU' 'DLTR' 'EBAY' 'EA' 'EXC'
#  'FAST' 'FISV' 'FTNT' 'GILD' 'HON' 'IDXX' 'ILMN' 'INTC' 'INTU' 'ISRG' 'JD'
#  'KDP' 'KLAC' 'KHC' 'LRCX' 'LCID' 'LULU' 'MAR' 'MRVL' 'MTCH' 'MELI' 'META'
#  'MCHP' 'MU' 'MSFT' 'MRNA' 'MDLZ' 'MNST' 'NTES' 'NFLX' 'NVDA' 'NXPI'
#  'ORLY' 'OKTA' 'ODFL' 'PCAR' 'PANW' 'PAYX' 'PYPL' 'PEP' 'PDD' 'QCOM'
#  'REGN' 'ROST' 'SGEN' 'SIRI' 'SWKS' 'SPLK' 'SBUX' 'SNPS' 'TMUS' 'TSLA'
#  'TXN' 'VRSN' 'VRSK' 'VRTX' 'WBA' 'WDAY' 'XEL' 'ZM' 'ZS']
# Enter the stock symbol: TSLA
# [*********************100%***********************]  1 of 1 completed
# AxesSubplot(0.125,0.125;0.775x0.755)
# ---------- plot for Open -----------
# AxesSubplot(0.125,0.125;0.775x0.755)
# ---------- plot for High -----------
# AxesSubplot(0.125,0.125;0.775x0.755)
# ---------- plot for Low -----------
# AxesSubplot(0.125,0.125;0.775x0.755)
# ---------- plot for Close -----------
# AxesSubplot(0.125,0.125;0.775x0.755)
# ---------- plot for Adj Close -----------
# AxesSubplot(0.125,0.125;0.775x0.755)
# ---------- plot for Volume -----------
# can we proceed (yes/no) ?yes
# Choose from list of stocks:
# ['ATVI' 'ADBE' 'ADP' 'ABNB' 'ALGN' 'GOOGL' 'GOOG' 'AMZN' 'AMD' 'AEP'
#  'AMGN' 'ADI' 'ANSS' 'AAPL' 'AMAT' 'ASML' 'AZN' 'TEAM' 'ADSK' 'BIDU'
#  'BIIB' 'BKNG' 'AVGO' 'CDNS' 'CHTR' 'CTAS' 'CSCO' 'CTSH' 'CMCSA' 'CEG'
#  'CPRT' 'COST' 'CRWD' 'CSX' 'DDOG' 'DXCM' 'DOCU' 'DLTR' 'EBAY' 'EA' 'EXC'
#  'FAST' 'FISV' 'FTNT' 'GILD' 'HON' 'IDXX' 'ILMN' 'INTC' 'INTU' 'ISRG' 'JD'
#  'KDP' 'KLAC' 'KHC' 'LRCX' 'LCID' 'LULU' 'MAR' 'MRVL' 'MTCH' 'MELI' 'META'
#  'MCHP' 'MU' 'MSFT' 'MRNA' 'MDLZ' 'MNST' 'NTES' 'NFLX' 'NVDA' 'NXPI'
#  'ORLY' 'OKTA' 'ODFL' 'PCAR' 'PANW' 'PAYX' 'PYPL' 'PEP' 'PDD' 'QCOM'
#  'REGN' 'ROST' 'SGEN' 'SIRI' 'SWKS' 'SPLK' 'SBUX' 'SNPS' 'TMUS' 'TSLA'
#  'TXN' 'VRSN' 'VRSK' 'VRTX' 'WBA' 'WDAY' 'XEL' 'ZM' 'ZS']
# Enter the stock symbol: vrtx
# [*********************100%***********************]  1 of 1 completed
# AxesSubplot(0.125,0.2;0.775x0.68)
# ---------- plot for Open -----------
# AxesSubplot(0.125,0.2;0.775x0.68)
# ---------- plot for High -----------
# AxesSubplot(0.125,0.2;0.775x0.68)
# ---------- plot for Low -----------
# AxesSubplot(0.125,0.2;0.775x0.68)
# ---------- plot for Close -----------
# AxesSubplot(0.125,0.2;0.775x0.68)
# ---------- plot for Adj Close -----------
# AxesSubplot(0.125,0.2;0.775x0.68)
# ---------- plot for Volume -----------
# can we proceed (yes/no) ?no
# No problem !

# %% [markdown]
# # **Moving Averages**

# %% [markdown]
# Since the stock prices changed very quickly, we can find the moving averages to find how the price of each stock gonna change.

# %%
df2=df
df2
# Out:
#               Datetime Stock Symbol              Company        Open  \
# 0       11/1/2022 9:30         ATVI  Activision Blizzard   73.260002
# 1       11/1/2022 9:31         ATVI  Activision Blizzard   73.720001
# 2       11/1/2022 9:32         ATVI  Activision Blizzard   73.800003
# 3       11/1/2022 9:33         ATVI  Activision Blizzard   73.720001
# 4       11/1/2022 9:34         ATVI  Activision Blizzard   73.519997
# ...                ...          ...                  ...         ...
# 38707  11/1/2022 15:56           ZS              Zscaler  150.475006
# 38708  11/1/2022 15:57           ZS              Zscaler  150.395004
# 38709  11/1/2022 15:58           ZS              Zscaler  150.384995
# 38710  11/1/2022 15:59           ZS              Zscaler  150.330002
# 38711  11/1/2022 16:00           ZS              Zscaler  150.389999
#
#              High         Low       Close   Adj Close  Volume
# 0       73.699997   73.260002   73.669998   73.669998  257668
# 1       73.930000   73.720001   73.750000   73.750000   71614
# 2       73.860001   73.720001   73.750000   73.750000   86779
# 3       73.750000   73.550003   73.550003   73.550003   24160
# 4       73.580002   73.470001   73.510002   73.510002   10151
# ...           ...         ...         ...         ...     ...
# 38707  150.500000  150.289993  150.395004  150.395004   21267
# 38708  150.419998  150.300003  150.369995  150.369995   20462
# 38709  150.434998  150.300003  150.300003  150.300003   20599
# 38710  150.490005  150.300003  150.470001  150.470001   43469
# 38711  150.389999  150.389999  150.389999  150.389999       0
#
# [38712 rows x 9 columns]

# %%
unq_list=df2['Stock Symbol'].unique()
while(True):
  process=str(input('can we proceed (yes/no) ?'))
  if(process=='yes'):
    print('Choose from list of stocks: ')
    print(unq_list)
    stock=(input('Enter the stock symbol: '))
    stock=stock.upper()
    df_ind= yf.download(tickers=stock,period='1d',interval='1m')
    df_ind['MA 50']=df_ind['Adj Close'].rolling(50).mean()
    df_ind['MA 100']=df_ind['Adj Close'].rolling(100).mean()
    print(df_ind[['Adj Close','MA 50','MA 100']].plot(figsize=(16,8)))
  else:
    print("No problem ! ")
    break
# Out:
# can we proceed (yes/no) ?yes
# Choose from list of stocks:
# ['ATVI' 'ADBE' 'ADP' 'ABNB' 'ALGN' 'GOOGL' 'GOOG' 'AMZN' 'AMD' 'AEP'
#  'AMGN' 'ADI' 'ANSS' 'AAPL' 'AMAT' 'ASML' 'AZN' 'TEAM' 'ADSK' 'BIDU'
#  'BIIB' 'BKNG' 'AVGO' 'CDNS' 'CHTR' 'CTAS' 'CSCO' 'CTSH' 'CMCSA' 'CEG'
#  'CPRT' 'COST' 'CRWD' 'CSX' 'DDOG' 'DXCM' 'DOCU' 'DLTR' 'EBAY' 'EA' 'EXC'
#  'FAST' 'FISV' 'FTNT' 'GILD' 'HON' 'IDXX' 'ILMN' 'INTC' 'INTU' 'ISRG' 'JD'
#  'KDP' 'KLAC' 'KHC' 'LRCX' 'LCID' 'LULU' 'MAR' 'MRVL' 'MTCH' 'MELI' 'META'
#  'MCHP' 'MU' 'MSFT' 'MRNA' 'MDLZ' 'MNST' 'NTES' 'NFLX' 'NVDA' 'NXPI'
#  'ORLY' 'OKTA' 'ODFL' 'PCAR' 'PANW' 'PAYX' 'PYPL' 'PEP' 'PDD' 'QCOM'
#  'REGN' 'ROST' 'SGEN' 'SIRI' 'SWKS' 'SPLK' 'SBUX' 'SNPS' 'TMUS' 'TSLA'
#  'TXN' 'VRSN' 'VRSK' 'VRTX' 'WBA' 'WDAY' 'XEL' 'ZM' 'ZS']
# Enter the stock symbol: tsla
# [*********************100%***********************]  1 of 1 completed
# AxesSubplot(0.125,0.125;0.775x0.755)
# can we proceed (yes/no) ?no
# No problem !

# %% [markdown]
# In both of these plots above, we can see how the price of the stock changes from second to second on the date 04/11.

# %%
df_ind
# Out:
#                            Open        High         Low       Close  \
# Datetime
# 2022-11-04 09:30:00  222.600006  223.789993  222.380005  223.570007
# 2022-11-04 09:31:00  223.600006  223.800003  222.850006  223.009995
# 2022-11-04 09:32:00  222.289993  222.300003  220.662994  220.740005
# 2022-11-04 09:33:00  220.391800  220.479904  219.773407  219.925003
# 2022-11-04 09:34:00  219.970001  220.580002  219.470001  219.603104
# ...                         ...         ...         ...         ...
# 2022-11-04 15:56:00  206.659302  206.970001  206.649994  206.955002
# 2022-11-04 15:57:00  206.949997  207.039993  206.860001  206.990005
# 2022-11-04 15:58:00  206.989899  207.070007  206.910004  206.979996
# 2022-11-04 15:59:00  206.990005  207.589996  206.979996  207.479996
# 2022-11-04 16:00:00  207.470001  207.470001  207.470001  207.470001
#
#                       Adj Close   Volume       MA 50      MA 100
# Datetime
# 2022-11-04 09:30:00  223.570007  2817687         NaN         NaN
# 2022-11-04 09:31:00  223.009995   201482         NaN         NaN
# 2022-11-04 09:32:00  220.740005   716521         NaN         NaN
# 2022-11-04 09:33:00  219.925003   500279         NaN         NaN
# 2022-11-04 09:34:00  219.603104   340201         NaN         NaN
# ...                         ...      ...         ...         ...
# 2022-11-04 15:56:00  206.955002   470228  207.077238  206.562895
# 2022-11-04 15:57:00  206.990005   476037  207.073738  206.585895
# 2022-11-04 15:58:00  206.979996   435777  207.067338  206.600180
# 2022-11-04 15:59:00  207.479996   817118  207.062938  206.619080
# 2022-11-04 16:00:00  207.470001        0  207.047338  206.641580
#
# [391 rows x 8 columns]

# %% [markdown]
# # **Target variable declared**

# %%
df_ind=df_ind.dropna(axis='columns')

# %%
df_ind.head()
# Out:
#                            Open        High         Low       Close  \
# Datetime
# 2022-11-04 09:30:00  222.600006  223.789993  222.380005  223.570007
# 2022-11-04 09:31:00  223.600006  223.800003  222.850006  223.009995
# 2022-11-04 09:32:00  222.289993  222.300003  220.662994  220.740005
# 2022-11-04 09:33:00  220.391800  220.479904  219.773407  219.925003
# 2022-11-04 09:34:00  219.970001  220.580002  219.470001  219.603104
#
#                       Adj Close   Volume
# Datetime
# 2022-11-04 09:30:00  223.570007  2817687
# 2022-11-04 09:31:00  223.009995   201482
# 2022-11-04 09:32:00  220.740005   716521
# 2022-11-04 09:33:00  219.925003   500279
# 2022-11-04 09:34:00  219.603104   340201

# %%
data=df2[['Close']]
data=data.rename(columns = {'Close':'Actual_Close'})
data
# Out:
#        Actual_Close
# 0         73.669998
# 1         73.750000
# 2         73.750000
# 3         73.550003
# 4         73.510002
# ...             ...
# 38707    150.395004
# 38708    150.369995
# 38709    150.300003
# 38710    150.470001
# 38711    150.389999
#
# [38712 rows x 1 columns]

# %%
data["Target"] = df2.rolling(2).apply(lambda x: x.iloc[1] > x.iloc[0])["Close"]

# %%
data['datetime']=df2['Datetime']
data.head(10)
# Out:
#    Actual_Close  Target        datetime
# 0     73.669998     NaN  11/1/2022 9:30
# 1     73.750000     1.0  11/1/2022 9:31
# 2     73.750000     0.0  11/1/2022 9:32
# 3     73.550003     0.0  11/1/2022 9:33
# 4     73.510002     0.0  11/1/2022 9:34
# 5     73.550003     1.0  11/1/2022 9:35
# 6     73.570000     1.0  11/1/2022 9:36
# 7     73.610001     1.0  11/1/2022 9:37
# 8     73.510002     0.0  11/1/2022 9:38
# 9     73.529999     1.0  11/1/2022 9:39

# %%
df2.head(10)
# Out:
#          Datetime Stock Symbol              Company       Open       High  \
# 0  11/1/2022 9:30         ATVI  Activision Blizzard  73.260002  73.699997
# 1  11/1/2022 9:31         ATVI  Activision Blizzard  73.720001  73.930000
# 2  11/1/2022 9:32         ATVI  Activision Blizzard  73.800003  73.860001
# 3  11/1/2022 9:33         ATVI  Activision Blizzard  73.720001  73.750000
# 4  11/1/2022 9:34         ATVI  Activision Blizzard  73.519997  73.580002
# 5  11/1/2022 9:35         ATVI  Activision Blizzard  73.510002  73.680000
# 6  11/1/2022 9:36         ATVI  Activision Blizzard  73.550003  73.599998
# 7  11/1/2022 9:37         ATVI  Activision Blizzard  73.570000  73.620003
# 8  11/1/2022 9:38         ATVI  Activision Blizzard  73.599998  73.599998
# 9  11/1/2022 9:39         ATVI  Activision Blizzard  73.529999  73.559998
#
#          Low      Close  Adj Close  Volume
# 0  73.260002  73.669998  73.669998  257668
# 1  73.720001  73.750000  73.750000   71614
# 2  73.720001  73.750000  73.750000   86779
# 3  73.550003  73.550003  73.550003   24160
# 4  73.470001  73.510002  73.510002   10151
# 5  73.500000  73.550003  73.550003   27652
# 6  73.529999  73.570000  73.570000   42681
# 7  73.529999  73.610001  73.610001   16017
# 8  73.495003  73.510002  73.510002   33473
# 9  73.500000  73.529999  73.529999   15799

# %%
df2_past = df2.copy()
df2_prev = df2_past.shift(1)
df2_prev.head(2)
# Out:
#          Datetime Stock Symbol              Company       Open       High  \
# 0             NaN          NaN                  NaN        NaN        NaN
# 1  11/1/2022 9:30         ATVI  Activision Blizzard  73.260002  73.699997
#
#          Low      Close  Adj Close    Volume
# 0        NaN        NaN        NaN       NaN
# 1  73.260002  73.669998  73.669998  257668.0

# %%
predictors = ["Close", "Volume", "Open", "High", "Low"]
data = data.join(df2_prev[predictors]).iloc[1:]

# %%
data.head()
# Out:
#    Actual_Close  Target        datetime      Close    Volume       Open  \
# 1     73.750000     1.0  11/1/2022 9:31  73.669998  257668.0  73.260002
# 2     73.750000     0.0  11/1/2022 9:32  73.750000   71614.0  73.720001
# 3     73.550003     0.0  11/1/2022 9:33  73.750000   86779.0  73.800003
# 4     73.510002     0.0  11/1/2022 9:34  73.550003   24160.0  73.720001
# 5     73.550003     1.0  11/1/2022 9:35  73.510002   10151.0  73.519997
#
#         High        Low
# 1  73.699997  73.260002
# 2  73.930000  73.720001
# 3  73.860001  73.720001
# 4  73.750000  73.550003
# 5  73.580002  73.470001

# %% [markdown]
# # **Shuffle data**

# %%
data1=data.reindex(np.random.permutation(data.index))
data1.head(10)
# Out:
#        Actual_Close  Target         datetime        Close   Volume  \
# 8147    1896.500000     1.0  11/1/2022 11:24  1895.180054    427.0
# 12938     81.459999     1.0  11/1/2022 11:28    81.379997   4724.0
# 32765      6.150000     1.0  11/1/2022 10:44     6.140000  10610.0
# 13346    119.455002     1.0  11/1/2022 11:46   119.209999   3088.0
# 107       73.544998     0.0  11/1/2022 11:17    73.544998   6272.0
# 3984     268.690002     0.0  11/1/2022 11:06   268.795013   3913.0
# 17670    386.815002     0.0  11/1/2022 12:34   387.434998    629.0
# 5811     476.700012     0.0  11/1/2022 10:04   477.660004   3968.0
# 16259    104.125000     1.0  11/1/2022 14:56   104.029999  18555.0
# 33784     82.919998     0.0  11/1/2022 15:11    82.930000   1768.0
#
#               Open         High          Low
# 8147   1893.310059  1895.180054  1893.310059
# 12938    81.470001    81.540001    81.364998
# 32765     6.145000     6.145000     6.140000
# 13346   119.160004   119.269997   119.160004
# 107      73.529999    73.550003    73.525002
# 3984    268.720001   268.795013   268.555695
# 17670   387.434998   387.434998   387.434998
# 5811    477.355011   478.350006   477.355011
# 16259   103.894997   104.029999   103.894997
# 33784    82.989998    82.989998    82.910004

# %% [markdown]
# # **Training a machine learning model**

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np
model = RandomForestClassifier(n_estimators=100, min_samples_split=300, random_state=1)

# %% [markdown]
# # **Splitting the data**

# %%
train = data1.iloc[:-100]
test = data1.iloc[-100:]

# %%
train.shape
# Out:
# (38611, 8)

# %%
test.shape
# Out:
# (100, 8)

# %% [markdown]
# # **Training the model with train data**

# %%
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=300, random_state=1)

# %% [markdown]
# # **Measuring Error**

# %%
# Evaluate error of predictions
pred = model.predict(test[predictors])
pred = pd.Series(pred, index=test.index)
precision_score(test["Target"], pred)
# Out:
# 0.37037037037037035

# %% [markdown]
# Random forest classifier is predicting the future price of the data based on the past data with 60% accuracy.

# %% [markdown]
# # **Plotting the input target and predict target**

# %%
output=pd.DataFrame(pred)
output['test output']=test['Target']
output.columns=['Prediction','Test Output']
output.head(10)
# Out:
#        Prediction  Test Output
# 20673         0.0          1.0
# 7341          1.0          0.0
# 3299          0.0          1.0
# 30797         0.0          1.0
# 2975          0.0          0.0
# 3758          0.0          1.0
# 16139         0.0          1.0
# 5488          0.0          1.0
# 2344          0.0          1.0
# 29615         0.0          1.0

# %%
output.plot()

# %% [markdown]
# # **DM Models**

# %% [markdown]
# # **Logistic regression**

# %%
data1.head()
# Out:
#        Actual_Close  Target         datetime        Close   Volume  \
# 8147    1896.500000     1.0  11/1/2022 11:24  1895.180054    427.0
# 12938     81.459999     1.0  11/1/2022 11:28    81.379997   4724.0
# 32765      6.150000     1.0  11/1/2022 10:44     6.140000  10610.0
# 13346    119.455002     1.0  11/1/2022 11:46   119.209999   3088.0
# 107       73.544998     0.0  11/1/2022 11:17    73.544998   6272.0
#
#               Open         High          Low
# 8147   1893.310059  1895.180054  1893.310059
# 12938    81.470001    81.540001    81.364998
# 32765     6.145000     6.145000     6.140000
# 13346   119.160004   119.269997   119.160004
# 107      73.529999    73.550003    73.525002

# %%
train_lr=data1.iloc[:,[0,3,4,5,6,7]]
test_lr=data1.iloc[:, [1]]

# %%
X_train, X_test, y_train, y_test = train_test_split(train_lr,test_lr,test_size=0.3, random_state=1)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)*100))
# Out:
# Accuracy of logistic regression classifier on test set: 77.18

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[5656,  468],
#        [2182, 3308]])

# %% [markdown]
# # **Support Vector Machines**

# %%
model = svm.SVC(kernel='poly', degree=2)
model.fit(X_train, y_train)

# %%
predictions_poly = model.predict(X_test)
accuracy_poly = accuracy_score(y_test, predictions_poly)
print("2nd degree polynomial Kernel\nAccuracy (normalized): " + str(accuracy_poly))

# %% [markdown]
# # **Stock price of Tesla after Musk took over the twitter**

# %%
tesla= yf.download(tickers="TSLA",period='10d',interval='1d')
print(tesla)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-24  205.820007  213.500000  198.589996  211.250000  211.250000
# 2022-10-25  210.100006  224.350006  210.000000  222.419998  222.419998
# 2022-10-26  219.399994  230.600006  218.199997  224.639999  224.639999
# 2022-10-27  229.770004  233.809998  222.850006  225.089996  225.089996
# 2022-10-28  225.399994  228.860001  216.350006  228.520004  228.520004
# 2022-10-31  226.190002  229.850006  221.940002  227.539993  227.539993
# 2022-11-01  234.050003  237.399994  227.279999  227.820007  227.820007
# 2022-11-02  226.039993  227.869995  214.820007  214.979996  214.979996
# 2022-11-03  211.360001  221.199997  210.139999  215.309998  215.309998
# 2022-11-04  222.600006  223.800003  203.080002  207.470001  207.470001
#
#                Volume
# Date
# 2022-10-24  100446800
# 2022-10-25   96507900
# 2022-10-26   85012500
# 2022-10-27   61638800
# 2022-10-28   69152400
# 2022-10-31   61554300
# 2022-11-01   62688800
# 2022-11-02   63070300
# 2022-11-03   56538800
# 2022-11-04   98453100

# %%
tesla.plot.line(figsize=(16,8))

# %%
tesla['Adj Close'].plot(figsize=(16,8))

# %% [markdown]
# When we observe the trend of the tesla Stock, I found out that the musk take over the twitter on 11-27-2022. since the news got out on the night itself, many investors prebooked the tesla stocks. As we can observe from the graph, the price reached its high on 28 october 2022. From the next 3 days, the price undergoes little change in the price of the stock. Recently a debate is going on about musk changing rules in twitter, this makes the price goes down to  $205. The same variation with the twitter too.
